# %%
# 1)
# For blue collar workers, the average predicted increase in salary for workers in foreign-owned firms compared to domestic firms is approximately 67%

# %%
# 2)
# Education was likely captured by the foreign owner dummy variable. So when holding education constant, the effect of foreign ownership on salary is reduced. Foreign firms likely employ more educated workers, which contributes to higher salaries.

# %%
# 3)
# You would subtract the -0.38 percentage points from the 1.29 to get the new full distance.

# %%
# 4)
# interaction terms: how much does my slope change per inclusion of another variable
